# %% [markdown]
# <a href="http://cocl.us/pytorch_link_top">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/Pytochtop.png" width="750" alt="IBM Product ">
# </a>

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork/image/IDSN-logo.png" width="200" alt="cognitiveclass.ai logo">

# %% [markdown]
# <h1><h1>Pre-trained-Models with PyTorch </h1>

# %% [markdown]
# In this lab, you will use pre-trained models to classify between the negative and positive samples; you will be provided with the dataset object. The particular pre-trained model will be resnet18; you will have three questions:
# <ul>
# <li>change the output layer</li>
# <li> train the model</li>
# <li>  identify  several  misclassified samples</li>
#  </ul>
# You will take several screenshots of your work and share your notebook.

# %% [markdown]
# <h2>Table of Contents</h2>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
#
# <ul>
#     <li><a href="#download_data"> Download Data</a></li>
#     <li><a href="#auxiliary"> Imports and Auxiliary Functions </a></li>
#     <li><a href="#data_class"> Dataset Class</a></li>
#     <li><a href="#Question_1">Question 1</a></li>
#     <li><a href="#Question_2">Question 2</a></li>
#     <li><a href="#Question_3">Question 3</a></li>
# </ul>
# <p>Estimated Time Needed: <strong>120 min</strong></p>
#  </div>
# <hr>

# %% [markdown]
# <h2 id="download_data">Download Data</h2>

# %% [markdown]
# Download the dataset and unzip the files in your data directory, unlike the other labs, all the data will be deleted after you close  the lab, this may take some time:

# %%
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip
# Out:
# ^C

# %%
# !unzip -q Positive_tensors.zip

# %%
# ! wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
# !unzip -q Negative_tensors.zip

# %% [markdown]
# We will install torchvision:

# %%
# !pip install torchvision

# %% [markdown]
# <h2 id="auxiliary">Imports and Auxiliary Functions</h2>

# %% [markdown]
# The following are the libraries we are going to use for this lab. The <code>torch.manual_seed()</code> is for forcing the random function to give the same number every time we try to recompile it.

# %%
# These are the libraries will be used for this lab.
import torchvision.models as models
from PIL import Image
import pandas
from torchvision import transforms
import torch.nn as nn
import time
import torch 
import matplotlib.pylab as plt
import numpy as np
from torch.utils.data import Dataset, DataLoader
import h5py
import os
import glob
torch.manual_seed(0)

# %%
from matplotlib.pyplot import imshow
import matplotlib.pylab as plt
from PIL import Image
import pandas as pd
import os

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="data_class">Dataset Class</h2>

# %% [markdown]
#  This dataset class is essentially the same dataset you build in the previous section, but to speed things up, we are going to use tensors instead of jpeg images. Therefor for each iteration, you will skip the reshape step, conversion step to tensors and normalization step.

# %%
# Create your own dataset object

class Dataset(Dataset):

    # Constructor
    def __init__(self,transform=None,train=True):
        directory= os.getcwd()
        positive="Positive_tensors"
        negative='Negative_tensors'

        positive_file_path=os.path.join(directory,positive)
        negative_file_path=os.path.join(directory,negative)
        positive_files=[os.path.join(positive_file_path,file) for file in os.listdir(positive_file_path) if file.endswith(".pt")]
        negative_files=[os.path.join(negative_file_path,file) for file in os.listdir(negative_file_path) if file.endswith(".pt")]
        number_of_samples=len(positive_files)+len(negative_files)
        self.all_files=[None]*number_of_samples
        self.all_files[::2]=positive_files
        self.all_files[1::2]=negative_files 
        # The transform is goint to be used on image
        self.transform = transform
        #torch.LongTensor
        self.Y=torch.zeros([number_of_samples]).type(torch.LongTensor)
        self.Y[::2]=1
        self.Y[1::2]=0
        
        if train:
            self.all_files=self.all_files[0:30000]
            self.Y=self.Y[0:30000]
            self.len=len(self.all_files)
        else:
            self.all_files=self.all_files[30000:]
            self.Y=self.Y[30000:]
            self.len=len(self.all_files)     
       
    # Get the length
    def __len__(self):
        return self.len
    
    # Getter
    def __getitem__(self, idx):
               
        image=torch.load(self.all_files[idx])
        y=self.Y[idx]
                  
        # If there is any transform method, apply it onto the image
        if self.transform:
            image = self.transform(image)

        return image, y
    
print("done")
# Out:
# done

# %% [markdown]
# We create two dataset objects, one for the training data and one for the validation data.

# %%
train_dataset = Dataset(train=True)
validation_dataset = Dataset(train=False)
print("done")
# Out:
# done

# %% [markdown]
# <h2 id="Question_1">Question 1</h2>

# %% [markdown]
# <b>Prepare a pre-trained resnet18 model :</b>

# %% [markdown]
# <b>Step 1</b>: Load the pre-trained model <code>resnet18</code> Set the parameter <code>pretrained</code> to true:

# %%
# Step 1: Load the pre-trained model resnet18

model = models.resnet18(pretrained=True)
# Out:
# c:\Users\pdhaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\pdhaw\AppData\Local\Programs\Python\Python311\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\pdhaw/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:10<00:00, 4.59MB/s]

# %% [markdown]
# <b>Step 2</b>: Set the attribute <code>requires_grad</code> to <code>False</code>. As a result, the parameters will not be affected by training.

# %%
# Step 2: Set the parameter cannot be trained for the pre-trained model

for param in model.parameters():
    param.requires_grad=False

# %% [markdown]
# <code>resnet18</code> is used to classify 1000 different objects; as a result, the last layer has 1000 outputs.  The 512 inputs come from the fact that the previously hidden layer has 512 outputs.

# %% [markdown]
# <b>Step 3</b>: Replace the output layer <code>model.fc</code> of the neural network with a <code>nn.Linear</code> object, to classify 2 different classes. For the parameters <code>in_features </code> remember the last hidden layer has 512 neurons.

# %%
model.fc = nn.Linear(512, 2)

# %% [markdown]
# Print out the model in order to show whether you get the correct answer.<br> <b>(Your peer reviewer is going to mark based on what you print here.)</b>

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# <h2 id="Question_2">Question 2: Train the Model</h2>

# %% [markdown]
# In this question you will train your, model:

# %% [markdown]
# <b>Step 1</b>: Create a cross entropy criterion function

# %%
# Step 1: Create the loss function

criterion = nn.CrossEntropyLoss()

# %% [markdown]
# <b>Step 2</b>: Create a training loader and validation loader object, the batch size should have 100 samples each.

# %%
train_loader = DataLoader(dataset=train_dataset, batch_size=100)
validation_loader = DataLoader(dataset=validation_dataset, batch_size=100)

# %% [markdown]
# <b>Step 3</b>: Use the following optimizer to minimize the loss

# %%
optimizer = torch.optim.Adam([parameters  for parameters in model.parameters() if parameters.requires_grad],lr=0.001)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# **Complete the following code to calculate  the accuracy on the validation data for one epoch; this should take about 45 minutes. Make sure you calculate the accuracy on the validation data.**

# %%
n_epochs=1
loss_list=[]
accuracy_list=[]
correct=0
N_test=len(validation_dataset)
N_train=len(train_dataset)
start_time = time.time()
#n_epochs

Loss=0
start_time = time.time()
for epoch in range(n_epochs):
    for batch_idx, (x, y) in enumerate(train_loader):
        model.train()
        # Clear gradient
        optimizer.zero_grad()
        # Make a prediction
        z = model(x)
        # Calculate loss
        loss = criterion(z, y)
        # Calculate gradients of parameters
        loss.backward()
        optimizer.step()
        loss_list.append(loss.item())

        # Print the current batch information for training
        print(f"Epoch [{epoch + 1}/{n_epochs}], Training Batch [{batch_idx + 1}/{len(train_loader)}], Training Loss: {loss.item():.4f}")

    correct = 0
    for x_test, y_test in validation_loader:
        # set model to eval
        model.eval()
        # make a prediction
        z = model(x_test)
        # find max
        _, yhat = torch.max(z.data, 1)
        # Calculate misclassified samples in mini-batch
        correct += (yhat == y_test).sum().item()

        # Print the current batch information for validation
        print(f"Epoch [{epoch + 1}/{n_epochs}], Validation Batch, Accuracy: {correct / N_test:.4f}")

    accuracy = correct / N_test
    accuracy_list.append(accuracy)
# Out:
# Epoch [1/1], Training Batch [1/300], Training Loss: 0.0274
# Epoch [1/1], Training Batch [2/300], Training Loss: 0.0162
# Epoch [1/1], Training Batch [3/300], Training Loss: 0.0427
# Epoch [1/1], Training Batch [4/300], Training Loss: 0.0083
# Epoch [1/1], Training Batch [5/300], Training Loss: 0.0102
# Epoch [1/1], Training Batch [6/300], Training Loss: 0.0234
# Epoch [1/1], Training Batch [7/300], Training Loss: 0.0162
# Epoch [1/1], Training Batch [8/300], Training Loss: 0.0104
# Epoch [1/1], Training Batch [9/300], Training Loss: 0.0239
# Epoch [1/1], Training Batch [10/300], Training Loss: 0.0190
# Epoch [1/1], Training Batch [11/300], Training Loss: 0.0196
# Epoch [1/1], Training Batch [12/300], Training Loss: 0.0302
# Epoch [1/1], Training Batch [13/300], Training Loss: 0.0115
# Epoch [1/1], Training Batch [14/300], Training Loss: 0.0355
# Epoch [1/1], Training Batch [15/300], Training Loss: 0.0328
# Epoch [1/1], Training Batch [16/300], Training Loss: 0.0151
# Epoch [1/1], Training Batch [17/300], Training Loss: 0.0140
# Epoch [1/1], Training Batch [18/300], Training Loss: 0.0148
# Epoch [1/1], Training Batch [19/300], Training Loss: 0.0140
# Epoch [1/1], Training Batch [20/300], Training Loss: 0.0135
# Epoch [1/1], Training Batch [21/300], Training Loss: 0.0072
# Epoch [1/1], Training Batch [22/300], Training Loss: 0.0066
# Epoch [1/1], Training Batch [23/300], Training Loss: 0.0255
# Epoch [1/1], Training Batch [24/300], Training Loss: 0.0203
# Epoch [1/1], Training Batch [25/300], Training Loss: 0.0077
# Epoch [1/1], Training Batch [26/300], Training Loss: 0.0245
# Epoch [1/1], Training Batch [27/300], Training Loss: 0.0071
# Epoch [1/1], Training Batch [28/300], Training Loss: 0.0280
# Epoch [1/1], Training Batch [269/300], Training Loss: 0.0158
# Epoch [1/1], Training Batch [270/300], Training Loss: 0.0189
# Epoch [1/1], Training Batch [271/300], Training Loss: 0.0036
# Epoch [1/1], Training Batch [272/300], Training Loss: 0.0180
# Epoch [1/1], Training Batch [273/300], Training Loss: 0.0248
# Epoch [1/1], Training Batch [274/300], Training Loss: 0.0100
# Epoch [1/1], Training Batch [275/300], Training Loss: 0.0254
# Epoch [1/1], Training Batch [276/300], Training Loss: 0.0181
# Epoch [1/1], Training Batch [277/300], Training Loss: 0.0070
# Epoch [1/1], Training Batch [278/300], Training Loss: 0.0087
# Epoch [1/1], Training Batch [279/300], Training Loss: 0.0194
# Epoch [1/1], Training Batch [280/300], Training Loss: 0.0213
# Epoch [1/1], Training Batch [281/300], Training Loss: 0.0044
# Epoch [1/1], Training Batch [282/300], Training Loss: 0.0170
# Epoch [1/1], Training Batch [283/300], Training Loss: 0.0099
# Epoch [1/1], Training Batch [284/300], Training Loss: 0.0273
# Epoch [1/1], Training Batch [285/300], Training Loss: 0.0132
# Epoch [1/1], Training Batch [286/300], Training Loss: 0.0110
# Epoch [1/1], Training Batch [287/300], Training Loss: 0.0176
# Epoch [1/1], Training Batch [288/300], Training Loss: 0.0053
# Epoch [1/1], Training Batch [289/300], Training Loss: 0.0058
# Epoch [1/1], Training Batch [290/300], Training Loss: 0.0078
# Epoch [1/1], Training Batch [291/300], Training Loss: 0.0086
# Epoch [1/1], Training Batch [292/300], Training Loss: 0.0232
# Epoch [1/1], Training Batch [293/300], Training Loss: 0.0048
# Epoch [1/1], Training Batch [294/300], Training Loss: 0.0061
# Epoch [1/1], Training Batch [295/300], Training Loss: 0.0055
# Epoch [1/1], Training Batch [296/300], Training Loss: 0.0291
# Epoch [1/1], Training Batch [297/300], Training Loss: 0.0319
# Epoch [1/1], Training Batch [298/300], Training Loss: 0.0051
# Epoch [1/1], Training Batch [299/300], Training Loss: 0.0075
# Epoch [1/1], Training Batch [300/300], Training Loss: 0.0480
# Epoch [1/1], Validation Batch, Accuracy: 0.0099
# Epoch [1/1], Validation Batch, Accuracy: 0.0196
# Epoch [1/1], Validation Batch, Accuracy: 0.0294
# Epoch [1/1], Validation Batch, Accuracy: 0.0392
# Epoch [1/1], Validation Batch, Accuracy: 0.0491
# Epoch [1/1], Validation Batch, Accuracy: 0.0590
# Epoch [1/1], Validation Batch, Accuracy: 0.0689
# Epoch [1/1], Validation Batch, Accuracy: 0.0788
# Epoch [1/1], Validation Batch, Accuracy: 0.0888
# Epoch [1/1], Validation Batch, Accuracy: 0.0988
# Epoch [1/1], Validation Batch, Accuracy: 0.1088
# Epoch [1/1], Validation Batch, Accuracy: 0.1188
# Epoch [1/1], Validation Batch, Accuracy: 0.1288
# Epoch [1/1], Validation Batch, Accuracy: 0.1388
# Epoch [1/1], Validation Batch, Accuracy: 0.1488
# Epoch [1/1], Validation Batch, Accuracy: 0.1588
# Epoch [1/1], Validation Batch, Accuracy: 0.1687
# Epoch [1/1], Validation Batch, Accuracy: 0.1787
# Epoch [1/1], Validation Batch, Accuracy: 0.1886
# Epoch [1/1], Validation Batch, Accuracy: 0.1986
# Epoch [1/1], Validation Batch, Accuracy: 0.2086
# Epoch [1/1], Validation Batch, Accuracy: 0.2186
# Epoch [1/1], Validation Batch, Accuracy: 0.2286
# Epoch [1/1], Validation Batch, Accuracy: 0.2385
# Epoch [1/1], Validation Batch, Accuracy: 0.2484
# Epoch [1/1], Validation Batch, Accuracy: 0.2583
# Epoch [1/1], Validation Batch, Accuracy: 0.2683
# Epoch [1/1], Validation Batch, Accuracy: 0.2783
# Epoch [1/1], Validation Batch, Accuracy: 0.2881
# Epoch [1/1], Validation Batch, Accuracy: 0.2981
# Epoch [1/1], Validation Batch, Accuracy: 0.3080
# Epoch [1/1], Validation Batch, Accuracy: 0.3180
# Epoch [1/1], Validation Batch, Accuracy: 0.3280
# Epoch [1/1], Validation Batch, Accuracy: 0.3380
# Epoch [1/1], Validation Batch, Accuracy: 0.3480
# Epoch [1/1], Validation Batch, Accuracy: 0.3580
# Epoch [1/1], Validation Batch, Accuracy: 0.3680
# Epoch [1/1], Validation Batch, Accuracy: 0.3780
# Epoch [1/1], Validation Batch, Accuracy: 0.3880
# Epoch [1/1], Validation Batch, Accuracy: 0.3980
# Epoch [1/1], Validation Batch, Accuracy: 0.4078
# Epoch [1/1], Validation Batch, Accuracy: 0.4177
# Epoch [1/1], Validation Batch, Accuracy: 0.4277
# Epoch [1/1], Validation Batch, Accuracy: 0.4377
# Epoch [1/1], Validation Batch, Accuracy: 0.4477
# Epoch [1/1], Validation Batch, Accuracy: 0.4577
# Epoch [1/1], Validation Batch, Accuracy: 0.4676
# Epoch [1/1], Validation Batch, Accuracy: 0.4776
# Epoch [1/1], Validation Batch, Accuracy: 0.4875
# Epoch [1/1], Validation Batch, Accuracy: 0.4974
# Epoch [1/1], Validation Batch, Accuracy: 0.5074
# Epoch [1/1], Validation Batch, Accuracy: 0.5173
# Epoch [1/1], Validation Batch, Accuracy: 0.5272
# Epoch [1/1], Validation Batch, Accuracy: 0.5372
# Epoch [1/1], Validation Batch, Accuracy: 0.5471
# Epoch [1/1], Validation Batch, Accuracy: 0.5571
# Epoch [1/1], Validation Batch, Accuracy: 0.5671
# Epoch [1/1], Validation Batch, Accuracy: 0.5771
# Epoch [1/1], Validation Batch, Accuracy: 0.5870
# Epoch [1/1], Validation Batch, Accuracy: 0.5970
# Epoch [1/1], Validation Batch, Accuracy: 0.6070
# Epoch [1/1], Validation Batch, Accuracy: 0.6169
# Epoch [1/1], Validation Batch, Accuracy: 0.6268
# Epoch [1/1], Validation Batch, Accuracy: 0.6368
# Epoch [1/1], Validation Batch, Accuracy: 0.6468
# Epoch [1/1], Validation Batch, Accuracy: 0.6568
# Epoch [1/1], Validation Batch, Accuracy: 0.6668
# Epoch [1/1], Validation Batch, Accuracy: 0.6767
# Epoch [1/1], Validation Batch, Accuracy: 0.6867
# Epoch [1/1], Validation Batch, Accuracy: 0.6967
# Epoch [1/1], Validation Batch, Accuracy: 0.7067
# Epoch [1/1], Validation Batch, Accuracy: 0.7167
# Epoch [1/1], Validation Batch, Accuracy: 0.7267
# Epoch [1/1], Validation Batch, Accuracy: 0.7367
# Epoch [1/1], Validation Batch, Accuracy: 0.7467
# Epoch [1/1], Validation Batch, Accuracy: 0.7567
# Epoch [1/1], Validation Batch, Accuracy: 0.7667
# Epoch [1/1], Validation Batch, Accuracy: 0.7767
# Epoch [1/1], Validation Batch, Accuracy: 0.7867
# Epoch [1/1], Validation Batch, Accuracy: 0.7967
# Epoch [1/1], Validation Batch, Accuracy: 0.8065
# Epoch [1/1], Validation Batch, Accuracy: 0.8165
# Epoch [1/1], Validation Batch, Accuracy: 0.8264
# Epoch [1/1], Validation Batch, Accuracy: 0.8364
# Epoch [1/1], Validation Batch, Accuracy: 0.8464
# Epoch [1/1], Validation Batch, Accuracy: 0.8564
# Epoch [1/1], Validation Batch, Accuracy: 0.8663
# Epoch [1/1], Validation Batch, Accuracy: 0.8763
# Epoch [1/1], Validation Batch, Accuracy: 0.8863
# Epoch [1/1], Validation Batch, Accuracy: 0.8963
# Epoch [1/1], Validation Batch, Accuracy: 0.9063
# Epoch [1/1], Validation Batch, Accuracy: 0.9162
# Epoch [1/1], Validation Batch, Accuracy: 0.9262
# Epoch [1/1], Validation Batch, Accuracy: 0.9362
# Epoch [1/1], Validation Batch, Accuracy: 0.9462
# Epoch [1/1], Validation Batch, Accuracy: 0.9562
# Epoch [1/1], Validation Batch, Accuracy: 0.9661
# Epoch [1/1], Validation Batch, Accuracy: 0.9761
# Epoch [1/1], Validation Batch, Accuracy: 0.9861
# Epoch [1/1], Validation Batch, Accuracy: 0.9961

# %% [markdown]
# <b>Print out the Accuracy and plot the loss stored in the list <code>loss_list</code> for every iteration and take a screen shot.</b>

# %%
accuracy
# Out:
# 0.9961

# %%
plt.plot(loss_list)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# <h2 id="Question_3">Question 3:Find the misclassified samples</h2>

# %% [markdown]
# <b>Identify the first four misclassified samples using the validation data:</b>

# %%
misclassified = []
for x_test, y_test in validation_loader:
    # set model to eval
    model.eval()
    # make a prediction
    z = model(x_test)
    # find max
    _, yhat = torch.max(z.data, 1)
    # Calculate misclassified samples in mini-batch
    correct += (yhat == y_test).sum().item()
    # Identify the first four misclassified samples

    if len(misclassified) < 4:
        for i in range(len(y_test)):
            if yhat[i] != y_test[i]:
                misclassified.append((x_test[i], yhat[i], y_test[i]))

for i, (x_mis, yhat_mis, y_true_mis) in enumerate(misclassified):
    print(f"Misclassified Sample {i + 1}: Predicted Class {yhat_mis}, True Class {y_true_mis}")
# Out:
# Misclassified Sample 1: Predicted Class 0, True Class 1
# Misclassified Sample 2: Predicted Class 1, True Class 0
# Misclassified Sample 3: Predicted Class 0, True Class 1
# Misclassified Sample 4: Predicted Class 0, True Class 1

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/share-notebooks.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01"> CLICK HERE </a> Click here to see how to share your notebook.

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-21  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>

# %% [markdown]
# Copyright &copy; 2018 <a href="cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu">cognitiveclass.ai</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01">MIT License</a>.
